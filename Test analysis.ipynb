# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
rep = pd.read_json?

# %%
rep = pd.read_json('corpus_xdata.json')

# %%
rep.head()
# Out:
#                                                             2003  \
# presidente                                                ciampi
# nb_token                                                    1526
# discorso_norm  care italiane cari italiani la notte di capoda...
# discorso_orig  Care italiane, cari italiani,\n\nla notte di C...
# piu_frequenti  {'istituzioni': 11, 'italia': 8, 'fiducia': 7,...
#
#                                                             2017  \
# presidente                                            mattarella
# nb_token                                                    1085
# discorso_norm  care concittadine e cari concittadini un salut...
# discorso_orig  Care concittadine e cari concittadini, un salu...
# piu_frequenti  {'vita': 5, 'anno': 5, 'italia': 4, 'sempre': ...
#
#                                                             1975  \
# presidente                                                 leone
# ...

# %%
final = rep.transpose()

# %%
final
# Out:
#       presidente nb_token                                      discorso_norm  \
# 2003      ciampi     1526  care italiane cari italiani la notte di capoda...
# 2017  mattarella     1085  care concittadine e cari concittadini un salut...
# 1975       leone     1326  italiani l inizio di un nuovo anno si saluta s...
# 1949     einaudi      187  nel rigoglio di intimi affetti suscitato da qu...
# 1993    scalfaro     2888  buona sera e buon anno a tutti in quest incont...
# ...          ...      ...                                                ...
# 1982     pertini     2337  italiani e italiane miei compatrioti come è co...
# 1979     pertini     2266  miei cari amici eccomi qui per la seconda volt...
# 1966     saragat     1163  italiani quest anno si chiude con una nota di ...
# 1968     saragat     1149  cari concittadini una consuetudine ormai conso...
# 2020  mattarella     1691  care concittadine e cari concittadini avvicina...
#
# ...

# %%
final.groupby('presidente').plot('nb_token')
# Out:
# presidente
# ciampi        AxesSubplot(0.125,0.125;0.775x0.755)
# cossiga       AxesSubplot(0.125,0.125;0.775x0.755)
# einaudi       AxesSubplot(0.125,0.125;0.775x0.755)
# gronchi       AxesSubplot(0.125,0.125;0.775x0.755)
# leone         AxesSubplot(0.125,0.125;0.775x0.755)
# mattarella    AxesSubplot(0.125,0.125;0.775x0.755)
# napolitano    AxesSubplot(0.125,0.125;0.775x0.755)
# pertini       AxesSubplot(0.125,0.125;0.775x0.755)
# saragat       AxesSubplot(0.125,0.125;0.775x0.755)
# scalfaro      AxesSubplot(0.125,0.125;0.775x0.755)
# segni         AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
