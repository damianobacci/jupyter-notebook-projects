# %% [markdown]
# # Storytelling Data Visualization on Exchange Rates
#
# This project will help me create some data storytelling using matplotlib.

# %%
import pandas as pd

exchange_rates = pd.read_csv('/Users/bacci/Datasets/euro-daily-hist_1999_2020.csv')

# %%
print(exchange_rates.head())
print(exchange_rates.tail())
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# As we can see the dataset has 41 columns, each one referred to a different currency, and 5699 rows, each referred to the € exchange rate for that currency in a day. Some of the currencies have null values: for example Greece introduce the € in 2002, and the dataset is starting from 1999, so it's natural that some values are missing. Slovenia is another example, albeit they introduce the € in 2007 (ditto for Slovakia and Cyprus).
#
# Since we are talkin about exchange rates we should expect numbers as the data type, instead we have objects (the time column should be a datetime).

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar', 'Period\\Unit:': 'Time'}, inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy() #copy the US dollar exchange rate into a new dataframe
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1797     6
#           ..
# 1.1555     1
# 1.4753     1
# 0.9583     1
# 1.0280     1
# 1.4903     1
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# We can see that there are 62 occurrenceof the '-' character, let's remove them.

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar.US_dollar != '-'] #remove - character un the US_dollar column
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float) #convert column from object to float

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()

plt.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'])
plt.show()

# %% [markdown]
# My objective now is rendering this data in a compelling and insightful way, using storytelling tips I learned during the course.

# %%
import matplotlib.style as style
style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'])

plt.show()

# %%
graph = (euro_to_dollar['Time'].dt.year >= 2006) & (euro_to_dollar['Time'].dt.year < 2010)
highlight = (euro_to_dollar['Time'].dt.year >= 2007) & (euro_to_dollar['Time'].dt.year < 2009)

graph_selected = euro_to_dollar[graph]
highlight_selected = euro_to_dollar[highlight]

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(graph_selected['Time'], graph_selected['rolling_mean'], linewidth=0.5, c='green')
ax.plot(highlight_selected['Time'], highlight_selected['rolling_mean'], linewidth=3, c='red')
ax.axvline(x=14045, c='grey', alpha=0.5, linewidth=60)
ax.set_xticklabels([2006, '', 2007, '', 2008, '', 2009, '', 2010])
ax.text(x=13000, y=1.7, s='Euro-USD rate peaked at 1.59 during the 2007-2008\'s financial crisis', size=15, weight='bold')
ax.text(x=13000, y=1.659, s='Euro-USD exchange rate between 2006 and 2010', size=14)

ax.text(13000, 1.1, '©DATAQUEST' + ' '*145 + 'European Central Bank', color = '#f0f0f0', backgroundcolor = '#4d4d4d', size=12)

plt.show()
# Out:
# <ipython-input-150-fea03221ceaf>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([2006, '', 2007, '', 2008, '', 2009, '', 2010])

# %%
bush = (euro_to_dollar['Time'].dt.year >= 2001) & (euro_to_dollar['Time'].dt.year < 2009)
obama = (euro_to_dollar['Time'].dt.year >= 2009) & (euro_to_dollar['Time'].dt.year < 2017)
trump = (euro_to_dollar['Time'].dt.year >= 2017) & (euro_to_dollar['Time'].dt.year < 2021)

bush_selected = euro_to_dollar[bush]
obama_selected = euro_to_dollar[obama]
trump_selected = euro_to_dollar[trump]


test = plt.figure(figsize=(18, 8))
gs = test.add_gridspec(2, 3)
f3_ax1 = test.add_subplot(gs[-1, :])
f3_ax1.plot(euro_to_dollar['Time'], euro_to_dollar['rolling_mean'])

f3_ax4 = test.add_subplot(gs[0, 0])
f3_ax4.set_title('Bush')
f3_ax4.plot(bush_selected['Time'], bush_selected['rolling_mean'])
f3_ax4.set_ylim([0.8,1.6])
f3_ax4.xaxis.set_major_locator(plt.MaxNLocator(6))

f3_ax5 = test.add_subplot(gs[0, 1])
f3_ax5.set_title('Obama')
f3_ax5.plot(obama_selected['Time'], obama_selected['rolling_mean'])
f3_ax5.set_ylim([0.8,1.6])
f3_ax5.xaxis.set_major_locator(plt.MaxNLocator(6))

f3_ax6 = test.add_subplot(gs[0, 2])
f3_ax6.set_title('Trump')
f3_ax6.plot(trump_selected['Time'], trump_selected['rolling_mean'])
f3_ax6.set_ylim([0.8,1.6])
f3_ax6.xaxis.set_major_locator(plt.MaxNLocator(6))

plt.show()
