# %%
#https://iechub.rfi.it/ArriviPartenze/ArrivalsDepartures/Monitor?placeId=1728&arrivals=False

# %%
import requests
from bs4 import BeautifulSoup

# %%
request = requests.get('https://iechub.rfi.it/ArriviPartenze/ArrivalsDepartures/Monitor?placeId=1728&arrivals=False')

# %%
soup = BeautifulSoup(request.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="it">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Stazione di MILANO CENTRALE
#   </title>
#   <script data-dtconfig="rid=RID_-1662435554|rpid=402905782|domain=rfi.it|reportUrl=/rb_bf79283hgk|app=2ced461eade821b5|rcdec=1209600000|featureHash=ICA27Vfgjqrux|vcv=2|rdnt=1|uxrgce=1|bp=3|srmcrv=10|cuc=68semmma|mel=100000|dpvc=1|ssv=4|lastModification=1658731324348|dtVersion=10209210209190405|srmcrl=1|tp=500,50,0,1|uxdcw=1500|agentUri=/ruxitagentjs_ICA27Vfgjqrux_10209210209190405.js" src="/ruxitagentjs_ICA27Vfgjqrux_10209210209190405.js" type="text/javascript">
#   </script>
#   <link href="/ArriviPartenze/Content/themes/base/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
#   <!-- Mobile -->
#   <link href="/ArriviPartenze/Content/Mobile/CommonStyle.css" media="screen and (max-device-width: 601px)" rel="stylesheet" type="text/css"/>
# ...
